# %%
import matplotlib.pyplot as plt
import numpy as np
notas=[12, 17, 74, 76, 87, 75 , 75, 16, 109, 90, 88, 93]
plt.hist(notas, bins=10,color='red', edgecolor='blue')
plt.title('Histograma de Notas')
plt.xlabel('Notas')
plt.ylabel('Frequencia')
plt.show()
