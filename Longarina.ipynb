# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
X=sp.symbols('x')
f=0.1*X**2 + 2*X
f_prime=sp.diff(f,x)
a=0
b=5
length=sp.integrate(sp.sqrt(1+f_prime**2),(x,a,b))
f_numeric=sp.lambdify(x,f,'numpy')
x_vals=np.linspace(a,b,100)
y_vals=f_numeric(x_vals)
plt.plot(x_vals,y_vals,label='$y=0.1xˆ2 +2x$')
plt.title('Curva da Longarina')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend()
plt.show()
print(f'O  comprimento da longarina entre x={a} e x={b} é aproximadamente {length.evalf()} unidade.')
# Out:
# O  comprimento da longarina entre x=0 e x=5 é aproximadamente 14.5770789921741 unidade.
